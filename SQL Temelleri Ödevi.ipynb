# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # ÖDEV1
# Kredi limiti (creditlimit) 100.000'den büyük olan tüm müşterilerin (-customers tablosundan) müşteri numarası, adı ve kredi limit bilgilerini creditlimit alanına göre sıralı bir şekilde gösteriniz.

# %% [raw]
# SELECT customerNumber, customerName, creditLimit
# FROM customers
# WHERE creditLimit > 100000
# ORDER BY creditLimit asc;

# %%
cevap1= pd.read_csv("sqlödev1.csv")
cevap1
# Out:
#     customerNumber                  customerName  creditLimit
# 0              157         Diecast Classics Inc.     100600.0
# 1              319                 Mini Classics     102700.0
# 2              148       Dragon Souveniers, Ltd.     103800.0
# 3              458    Corrida Auto Replicas, Ltd     104600.0
# 4              239  Collectable Mini Designs Co.     105000.0
# 5              321      Corporate Gift Ideas Co.     105000.0
# 6              276       Anna's Decorations, Ltd     107800.0
# 7              496             Kelly's Gift Shop     110000.0
# 8              249            Amica Models & Co.     113000.0
# 9              363  Online Diecast Creations Co.     114200.0
# 10             131             Land of Toys Inc.     114900.0
# 11             448       Scandinavian Gift Ideas     116400.0
# 12             114    Australian Collectors, Co.     117300.0
# 13             119             La Rochelle Gifts     118200.0
# 14             278                 Rovelli Gifts     119600.0
# 15             259       Toms Spezialitäten, Ltd     120400.0
# 16             227          Heintze Collectables     120800.0
# 17             386           L'ordine Souveniers     121400.0
# 18             286          Marta's Replicas Co.     123700.0
# 19             146        Saveley & Henriot, Co.     123900.0
# 20             187                AV Stores, Co.     136800.0
# 21             151            Muscle Machine Inc     138500.0
# 22             298               Vida Sport, Ltd     141300.0
# 23             124  Mini Gifts Distributors Ltd.     210500.0
# 24             141        Euro+ Shopping Channel     227600.0

# %% [markdown]
# # ÖDEV2
# customers tablosundan customernumber bilgisi 151 olan kaydın her sütununu gösteriniz.

# %% [raw]
# select *
#     from customers
#     where customerNumber=151;

# %%
cevap2= pd.read_csv("sqlödev2.csv")
cevap2
# Out:
#    customerNumber        customerName contactLastName contactFirstName  \
# 0             151  Muscle Machine Inc           Young             Jeff
#
#         phone       addressLine1 addressLine2 city state  postalCode country  \
# 0  2125557413  4092 Furth Circle    Suite 400  NYC    NY       10022     USA
#
#    salesRepEmployeeNumber  creditLimit
# 0                    1286     138500.0

# %% [markdown]
# # ÖDEV3
# Posta kodu (postalcode) 10022 olan müşterilerin kredi limit bilgilerini azalan sırada gösteriniz.

# %% [raw]
# SELECT customerName, creditLimit, postalCode
# FROM customers
# WHERE postalCode=10022
# ORDER BY creditLimit desc;

# %%
cevap3= pd.read_csv("sqlödev3.csv")
cevap3
# Out:
#            customerName  creditLimit  postalCode
# 0    Muscle Machine Inc     138500.0       10022
# 1     Land of Toys Inc.     114900.0       10022
# 2       Vitachrome Inc.      76400.0       10022
# 3  Classic Legends Inc.      67500.0       10022
# 4       Microscale Inc.      39800.0       10022
