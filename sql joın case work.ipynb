# %%
import pandas as pd

# %% [markdown]
# # Ödev
# Müşteri sayısı:
#
# 20’dan fazla olan ülkeler büyük ülke,
# 10 ile 20 arası orta,
# 10’dan az olanlar ise küçük ülke
# olacak olursa kaç tane büyük,orta, küçük ülke vardır?

# %%
WITH musteri AS (
SELECT
country as ulke,
count(*) as musteri_sayisi
FROM
customers
GROUP BY
ulke
ORDER BY musteri_sayisi DESC)
SELECT
musteri_sayisi, ulke,
CASE 
	when musteri_sayisi>20 THEN 'Büyük Ülke'
	when musteri_sayisi>10 THEN 'Orta Ülke'
	ELSE 'Küçük Ülke'
	END AS Ülke_Statü
FROM
musteri;

# %%
cevap1= pd.read_csv("sqlödev3-1.csv")
cevap1
# Out:
#     musteri_sayisi          ulke  Ülke_Statü
# 0               36           USA  Büyük Ülke
# 1               13       Germany   Orta Ülke
# 2               12        France   Orta Ülke
# 3                7         Spain  Küçük Ülke
# 4                5     Australia  Küçük Ülke
# 5                5            UK  Küçük Ülke
# 6                4         Italy  Küçük Ülke
# 7                4   New Zealand  Küçük Ülke
# 8                3        Norway  Küçük Ülke
# 9                3     Singapore  Küçük Ülke
# 10               3       Finland  Küçük Ülke
# 11               3        Canada  Küçük Ülke
# 12               3   Switzerland  Küçük Ülke
# 13               2        Sweden  Küçük Ülke
# 14               2       Denmark  Küçük Ülke
# 15               2      Portugal  Küçük Ülke
# 16               2         Japan  Küçük Ülke
# 17               2       Ireland  Küçük Ülke
# 18               2       Belgium  Küçük Ülke
# 19               2       Austria  Küçük Ülke
# 20               1        Poland  Küçük Ülke
# 21               1     Hong Kong  Küçük Ülke
# 22               1   Netherlands  Küçük Ülke
# 23               1  South Africa  Küçük Ülke
# 24               1   Philippines  Küçük Ülke
# 25               1        Russia  Küçük Ülke
# 26               1        Israel  Küçük Ülke
